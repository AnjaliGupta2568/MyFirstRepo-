# %% [markdown]
# #     * PYTHON *

# %% [markdown]
# # #Variable

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %%
1+3   #addition
# Out:
# 4

# %%
2 * 4   #Multiplication
# Out:
# 8

# %%
9 - 4     #subtraction
# Out:
# 5

# %%
25/4       #division
# Out:
# 6.25

# %%
25 // 4   #integer division
# Out:
# 6

# %%
3 ** 5    #exponential
# Out:
# 243

# %%
2 * ( 3 + 4 ) - 8       #BODMAS rule
# Out:
# 6

# %%
28 % 4   #Modulus
# Out:
# 0

# %%
x = 2       # x is variable/object/identifier, 2 is the value
x
# Out:
# 2

# %%
x + 5
# Out:
# 7

# %%
x + 9
# Out:
# 11

# %%
y = 4
y
# Out:
# 4

# %%
x + y
# Out:
# 6

# %%
x = 8
x
# Out:
# 8

# %%
x + y
# Out:
# 12

# %%
x + 10
# Out:
# 18

# %%
y
# Out:
# 4

# %%
y = 6
y
# Out:
# 6

# %%
name = 'Nit'    #string variable
name
# Out:
# 'Nit'

# %%
name + 'technology'   #concatenate
# Out:
# 'Nittechnology'

# %%
name + ' technology'
# Out:
# 'Nit technology'

# %%
name
# Out:
# 'Nit'

# %%
len(name)     # gives length of string
# Out:
# 3

# %%
com = 2 + 3j   #complex varable
com
# Out:
# (2+3j)

# %%
f = 34.9     #float variable
f
# Out:
# 34.9

# %%
b = True
b
# Out:
# True

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # #Datatypes

# %%
# *int  *float  *string  *bool  *complex

# %%
type(x)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
type(com)
# Out:
# complex

# %%
type(f)
# Out:
# float

# %%
type(b)
# Out:
# bool

# %%
i = 34
f = 112.56
print(i)
print(f)
# Out:
# 34
# 112.56

# %%
i + f
# Out:
# 146.56

# %%
i - f
# Out:
# -78.56

# %%
i * f
# Out:
# 3827.04

# %%
#bool
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False     #by default True =1 and False =0
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
False + True
# Out:
# 1

# %%
True / True
# Out:
# 1.0

# %%
True // True
# Out:
# 1

# %%
False / True
# Out:
# 0.0

# %%
s = 'Hello'      #string
s
# Out:
# 'Hello'

# %%
s1 = "Hello"
s1
# Out:
# 'Hello'

# %%
s2 = '''Hello'''
s2
# Out:
# 'Hello'

# %%
s3 = '''Hello                # use triple quot
           Team'''
s3
# Out:
# 'Hello \n           Team'

# %%
c = 10 + 20j      # complex
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c = 10 + 20j
d = 20 + 50j
print(c + d)
# Out:
# (30+70j)

# %%
print(c - d)
# Out:
# (-10-30j)

# %%
print(c * d)
# Out:
# (-800+900j)

# %%
print(c / d)
# Out:
# (0.41379310344827586-0.034482758620689655j)

# %% [markdown]
# # #Type Casting ==Convert one datatype to other datatype

# %%
# ----integer

# %%
int(35.67)  # only one parameter
# Out:
# 35

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(true)     # give error because of case sensitve

# %%
int('10')
# Out:
# 10

# %%
int(3 + 2j)    # give error

# %%
# -----Float

# %%
float(305000)
# Out:
# 305000.0

# %%
float(30,40)    #error because at most one argument

# %%
float(2+3j)    #error argument must be a string or a real no.  ,not complex

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('4')
# Out:
# 4.0

# %%
float('four')    #error

# %%
# -----string

# %%
str(8)
# Out:
# '8'

# %%
str(7.8)
# Out:
# '7.8'

# %%
str(4 + 7j)
# Out:
# '(4+7j)'

# %%
str(True,False)   # error must be string not bool

# %%
str(True)
# Out:
# 'True'

# %%
str()
# Out:
# ''

# %%
# ----bool

# %%
bool(10)    # non-zero value return True
# Out:
# True

# %%
bool(3.4)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool('45')
# Out:
# True

# %%
bool('Ten')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('0')
# Out:
# True

# %%
bool(3 + 5j)
# Out:
# True

# %%
# ----complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(20,30)
# Out:
# (20+30j)

# %%
complex(20,10,40)     # give error

# %%
complex(10.3,56.3)
# Out:
# (10.3+56.3j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')     # error if first is string then it can't take other

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,True)
# Out:
# 1j

# %% [markdown]
# # #String Indexing

# %%
# Forward indexing ----left to right(start from 0)
# Backward indexing ---right to left(start from -1)

# %%
s = 'Python'
s
# Out:
# 'Python'

# %%
s[0]
# Out:
# 'P'

# %%
s[2]
# Out:
# 't'

# %%
s[5]
# Out:
# 'n'

# %%
s[-1]
# Out:
# 'n'

# %%
s[-2]
# Out:
# 'o'

# %%
s[-6]
# Out:
# 'P'

# %%
str = 'world'
str
# Out:
# 'world'

# %%
print(str[0])
print(str[1])
print(str[2])
print(str[3])
print(str[4])
# Out:
# w
# o
# r
# l
# d

# %%
print(str[-1])
print(str[-2])
print(str[-3])
print(str[-4])
print(str[-5])
# Out:
# d
# l
# r
# o
# w

# %%
len(str)
# Out:
# 5

# %% [markdown]
# # #string Slicing,id(),len()

# %%
str = 'HelloPython'
str
# Out:
# 'HelloPython'

# %%
s = 'hello'
s
# Out:
# 'hello'

# %%
s[:]      # print all elements
# Out:
# 'hello'

# %%
s[0:4]     # print elements from 0 to (4-1) means last (n-1)
# Out:
# 'hell'

# %%
s[1:4]
# Out:
# 'ell'

# %%
s[4:4]
# Out:
# ''

# %%
str
# Out:
# 'HelloPython'

# %%
str[0:6]
# Out:
# 'HelloP'

# %%
s[2:]      #start from 2 till last
# Out:
# 'llo'

# %%
s[:4]      #start from 0 to 3rd index
# Out:
# 'hell'

# %%
str
# Out:
# 'HelloPython'

# %%
str[::3]    #print start to last index print only 3rd index
# Out:
# 'Hlyo'

# %%
str[::-1]   #print the element in reverse
# Out:
# 'nohtyPolleH'

# %%
s[::-1]
# Out:
# 'olleh'

# %%
str[::-2]      # print the element in reverse -2 index position
# Out:
# 'nhyolH'

# %%
s[::-2]
# Out:
# 'olh'

# %%
str
# Out:
# 'HelloPython'

# %%
str[0:10:2]    #print index 0 to 9th index but print every 2nd index count skip other index
# Out:
# 'Hloyh'

# %%
str[1:8:2]
# Out:
# 'elPt'

# %%
str
# Out:
# 'HelloPython'

# %%
str[0] = 'd'    #give error string in python are immutable

# %%
len(str)
# Out:
# 11

# %%
# ID() ---- variable address

# %%
num = 5
id(num)
# Out:
# 140707912528936

# %%
name ='nit'
id(name)
# Out:
# 1470582401920

# %%
a = 10
id(num)
# Out:
# 140707912528936

# %%
b = a
id(b)
# Out:
# 140707912529096

# %%
k =13
id(k)
# Out:
# 140707912529192

# %%
a = 20
id(a)     #as we change value of a then address will change
# Out:
# 140707912529416

# %% [markdown]
# # #Python Operator

# %%
# ---Arithmetic Operator

# %%
x1 , y1 = 10 , 5

# %%
x1
y1
# Out:
# 5

# %%
print(x1)
print(y1)
# Out:
# 10
# 5

# %%
x1 + y1   # addition
# Out:
# 15

# %%
x1 - y1    #subtraction
# Out:
# 5

# %%
x1 * y1     #multiplication
# Out:
# 50

# %%
x1 / y1     #division
# Out:
# 2.0

# %%
x1 ** y1    #exponential
# Out:
# 100000

# %%
x1 // y1    #integer division
# Out:
# 2

# %%
x1 % y1  # Modulus
# Out:
# 0

# %%
x1 + (x1 * y1) + y1 -(x1 / y1)
# Out:
# 63.0

# %%
#  ------Assignment operator

# %%
x = 4

# %%
x = x + 2   #if you want to increment by 2

# %%
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 8

# %%
x *= 3
x
# Out:
# 24

# %%
x -= 5
x
# Out:
# 19

# %%
x /= 4
x
# Out:
# 4.75

# %%
x //= 4
x
# Out:
# 1.0

# %%
a , b , c = 5 , 6 , 7   #you can assigned variable in one line

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
c
# Out:
# 7

# %%
# ------Unary opertor

# %%
n = 8  
n
# Out:
# 8

# %%
m = -(n)  #negation
m
# Out:
# -8

# %%
n
# Out:
# 8

# %%
-n
# Out:
# -8

# %%
# -------Relational operator

# %%
a = 7
b = 8

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b     # a=b we cannot use = operator  that means it is assigning
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b = 7

# %%
a == b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
# -----Logical Operator

# %%
a = 8
b = 3

# %%
a < 9 and b < 8   # refers to the truth table
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 9 or b < 2
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x   # you can reverse the operation
# Out:
# True

# %% [markdown]
# # #Bitwise Operator

# %%
# ---Number system conversion (bit - binary digit)

# %%
25
# Out:
# 25

# %%
bin(25)     # bin() for binary
# Out:
# '0b11001'

# %%
0b11001
# Out:
# 25

# %%
0b1100
# Out:
# 12

# %%
int(0b1100)
# Out:
# 12

# %%
bin(35)
# Out:
# '0b100011'

# %%
oct(25)     # oct() for octal
# Out:
# '0o31'

# %%
0o143
# Out:
# 99

# %%
0o17
# Out:
# 15

# %%
hex(9)     # hex() for hexadecimal
# Out:
# '0x9'

# %%
0xf
# Out:
# 15

# %%
0xad
# Out:
# 173

# %%
hex(25)
# Out:
# '0x19'

# %%
# ----6 bitwise operator 
# *complement(~) ,AND(&) ,OR(|) ,XOR(^) ,left shift(<<) ,right shift(>>)

# %%
print(bin(12))
print(bin(35))
# Out:
# 0b1100
# 0b100011

# %%
~12      #complement
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
~-30
# Out:
# 29

# %%
~-1
# Out:
# 0

# %%
print(bin(12))
print(bin(13))
# Out:
# 0b1100
# 0b1101

# %%
12 & 13   #AND
# Out:
# 12

# %%
1 & 1
# Out:
# 1

# %%
1 & 0
# Out:
# 0

# %%
35 & 40
# Out:
# 32

# %%
12 | 13  # OR
# Out:
# 13

# %%
1 | 1
# Out:
# 1

# %%
1 | 0
# Out:
# 1

# %%
35 | 40
# Out:
# 43

# %%
12 ^ 13  #XOR.
# Out:
# 1

# %%
1 ^ 1
# Out:
# 0

# %%
0 ^ 0
# Out:
# 0

# %%
1 ^ 0
# Out:
# 1

# %%
23 ^ 76
# Out:
# 91

# %%
print(bin(20))
print(bin(10))
# Out:
# 0b10100
# 0b1010

# %%
20 << 4    #left shift   means 4bits are gaining
# Out:
# 320

# %%
10 << 3
# Out:
# 80

# %%
10 >> 2   #right shift means 2 bits losing
# Out:
# 2

# %%
20 >> 3
# Out:
# 2

# %% [markdown]
# # #Swap variable in python

# %%
a = 4 
b = 7

# %%
a = b
b = a

# %%
a , b = b , a

# %%
print(a)
print(b)
# Out:
# 7
# 7

# %%
# in above scenario we lost value 4
a1 = 6
b1 = 8

# %%
temp = a1        # swap variable using third variable
a1 = b1
b1 = temp

# %%
print(a1)
print(b1)
# Out:
# 8
# 6

# %%
a2 = 4 
b2 = 2

# %%
a2 = a2 + b2      #without using third variable
b2 = a2 - b2
a2 = a2 - b2

# %%
print(a2)
print(b2)
# Out:
# 2
# 4

# %%
a3 = 9 
b3 = 5

# %%
a3 = a3 ^ b3      # using bitwise operator
b3 = a3 ^ b3
a3 = a3 ^ b3

# %%
print(a3)
print(b3)
# Out:
# 5
# 9

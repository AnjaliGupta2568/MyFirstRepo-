# %% [markdown]
# # #Number System Conversion (binary digit)

# %% [raw]
# *Binary

# %%
24
# Out:
# 24

# %%
bin(24)
# Out:
# '0b11000'

# %%
0b11000
# Out:
# 24

# %%
int(0b11011)
# Out:
# 27

# %%
bin(145)
# Out:
# '0b10010001'

# %%
int(0b100100111)
# Out:
# 295

# %% [raw]
# *Octal

# %%
oct(15)
# Out:
# '0o17'

# %%
0o17
# Out:
# 15

# %%
oct(2355)
# Out:
# '0o4463'

# %%
int(0o4462)
# Out:
# 2354

# %% [raw]
# *hexadecimal

# %%
hex(28)
# Out:
# '0x1c'

# %%
0x1f
# Out:
# 31

# %%
hex(36178)
# Out:
# '0x8d52'

# %%
int(0x8d79)
# Out:
# 36217

# %%
0xa
# Out:
# 10

# %% [markdown]
# # #import math module

# %%
import math     # math is module

# %%
x = math.sqrt(25)  #sqrt is inbuild function 
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
print(math.floor(2.4))     #floor - minimum or least value
# Out:
# 2

# %%
print(math.ceil(3.3))      #ceil - maximum or highest value
# Out:
# 4

# %%
print(math.pow(3,5))
# Out:
# 243.0

# %%
print(math.pi)           #these are constant
# Out:
# 3.141592653589793

# %%
print(math.e)            #these are constant
# Out:
# 2.718281828459045

# %%
import math as m
m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
from math import sqrt,pow          # math has many function if you want to call specific function then you use from 
pow(2,5)
# Out:
# 32.0

# %%
round(pow(2,3))       # to  remove decimal
# Out:
# 8

# %%
round(pow(2,5))
# Out:
# 32

# %%
#help(math)

# %% [markdown]
# # #user input function || command line input

# %%
x = input()
y = input()
z = x + y
print(z) # console is waiting for user to enter input 
# also if you work in idle
# Out:
#  23
#  34
# 2334

# %%
x1 = input('Enter the 1st number') #whenevery you works in input function it always give you string 
y1 = input('Enter the 2nd number') # it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# Enter the 1st number python
# Enter the 2nd number  world
# python world

# %%
x1 = input('Enter the 1st number') #whenevery you works in input function it always give you string 
y1 = input('Enter the 2nd number') # it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# Enter the 1st number 78
# Enter the 2nd number   34
# 78   34

# %%
type(x1)
type(y1)
# Out:
# str

# %%
x1 = input('Enter the 1st number') #whenevery you works in input function it always give you string 
a1 = int(x1)
y1 = input('Enter the 2nd number') # it wont understand as arithmetic operator
b1 = int(y1)
z1 = a1 + b1
print(z1)
# Out:
# Enter the 1st number 23
# Enter the 2nd number  34
# 57

# %%
x1 = input('Enter the 1st number') #whenevery you works in input function it always give you string 
a1 = float(x1)
y1 = input('Enter the 2nd number') # it wont understand as arithmetic operator
b1 = float(y1)
z1 = a1 + b1
print(z1)
# Out:
# Enter the 1st number 3.5
# Enter the 2nd number 2.1
# 5.6

# %%
x2 = int(input('Enter the 1st number'))
y2 = int(input('Enter the 2nd number'))
z2 = x2 * y2
z2
# Out:
# Enter the 1st number 23
# Enter the 2nd number 2
# 46

# %%
x2 = int(input('Enter the 1st number'))
y2 = int(input('Enter the 2nd number'))
z2 = x2 / y2
z2
# Out:
# Enter the 1st number 56
# Enter the 2nd number 7
# 8.0

# %%
ch = input('enter a char')
print(ch)
# Out:
# enter a char app
# app

# %%
ch = input('enter a char')
print(ch)
# Out:
# enter a char Python
# Python

# %%
print(ch[0])
# Out:
# P

# %%
print(ch[2])
# Out:
# t

# %%
print(ch[-1])
# Out:
# n

# %%
print(ch[1:])
# Out:
# ython

# %%
print(ch[0:5:2])
# Out:
# Pto

# %%
ch = input('enter a char')[0]
print(ch)
# Out:
# enter a char rt
# r

# %%
ch = input('enter a char')[0]
print(ch)
# Out:
# enter a char n
# n

# %%
ch = input('enter a char')[1:3]
print(ch)
# Out:
# enter a char as
# s

# %%
ch = input('enter a char')
print(ch) # if you enter as 2 + 6 -1 we get output as 2 + 6-1 only
# Out:
# enter a char on
# on

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 23 + 12 - 23
# 12

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 68 / 23 +18 -6 * 34
# -183.04347826086956

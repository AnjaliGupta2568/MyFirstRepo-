# %% [markdown]
# # #Manipulating strings

# %% [markdown]
# # 1.Escape characters

# %%
# \n  = newline
print(" Hello!\n What is your name? \n How are you?.")
# Out:
#  Hello!
#  What is your name?
#  How are you?.

# %%
# \t = tab
print("Hello!\t What is your name?\tHow are you?.")
# Out:
# Hello!	 What is your name?	How are you?.

# %%
# \r = carriage return
print(" What is your name?\rHow are you?")
# Out:
# How are you?r name?

# %% [markdown]
# # 2.Multiline Strings

# %%
print(
    """Dear Python,

    Your code has been stolen,
    and what are you do?

    Sincerely,
    Bob"""
)
# Out:
# Dear Python,
#
#     Your code has been stolen,
#     and what are you do?
#
#     Sincerely,
#     Bob

# %% [markdown]
# # 3.Indexing and Slicing strings

# %%
#indexing

# %%
str = 'Hello Python!'
str
# Out:
# 'Hello Python!'

# %%
str[0]
# Out:
# 'H'

# %%
str[6]
# Out:
# 'P'

# %%
str[-1]
# Out:
# '!'

# %%
#slicing

# %%
str
# Out:
# 'Hello Python!'

# %%
str[:]
# Out:
# 'Hello Python!'

# %%
str[:5]
# Out:
# 'Hello'

# %%
str[5:]
# Out:
# ' Python!'

# %%
str[0:4]
# Out:
# 'Hell'

# %%
str[:-1]
# Out:
# 'Hello Python'

# %%
str[::-1]
# Out:
# '!nohtyP olleH'

# %%
str[6:-1]
# Out:
# 'Python'

# %% [markdown]
# # 4.'in' and 'not in' operators

# %% [raw]
# # in operator

# %%
'Your' in 'Your name'
# Out:
# True

# %%
'hello' in 'hello'
# Out:
# True

# %%
'hello' in 'Your name'
# Out:
# False

# %%
'' in 'spam'
# Out:
# True

# %% [raw]
# # not in operator

# %%
'horse' not in 'horse and dogs'
# Out:
# False

# %%
'cat'  not in 'horse and dogs'
# Out:
# True

# %% [markdown]
# # 5.upper(),lower() and title()

# %%
greet = 'Welcome world!'

# %%
greet.upper()
# Out:
# 'WELCOME WORLD!'

# %%
greet.lower()
# Out:
# 'welcome world!'

# %%
greet.title()
# Out:
# 'Welcome World!'

# %% [markdown]
# # 6.isupper() and islower() methods

# %%
name = " Nareshit "

# %%
name.islower()
# Out:
# False

# %%
name.isupper()
# Out:
# False

# %%
'NARESHIT'.isupper()
# Out:
# True

# %%
'nareshit'.islower()
# Out:
# True

# %%
'123'.islower()
# Out:
# False

# %%
'123'.isupper()
# Out:
# False

# %%
'abc123'.islower()
# Out:
# True

# %% [markdown]
# # 7. is X string methods

# %% [raw]
# #isalpha()   = returns `True` if the string consists only of letters.

# %%
'nareshit'.isalpha()
# Out:
# True

# %% [raw]
#  isalnum() =  returns `True` if the string consists only of letters and numbers.

# %%
'abc123'.isalnum()
# Out:
# True

# %% [raw]
# isdecimal() = returns `True` if the string consists only of numbers

# %%
'123'.isdecimal()
# Out:
# True

# %% [raw]
# isspace() = returns `True` if the string consists only of spaces, tabs, and new-lines.

# %%
"\tHow are you?.".isspace()
# Out:
# False

# %% [raw]
#  istitle() =  returns `True` if the string consists only of words that begin with an
#  uppercase letter followed by only lowercase characters.

# %%
'Manipulating '.istitle()
# Out:
# True

# %%
'manipulating '.istitle()
# Out:
# False

# %% [markdown]
# # 8.startswith() and endswith()

# %%
'Introduce program'.startswith('Introduce')
# Out:
# True

# %%
'Introduce program'.endswith('program')
# Out:
# True

# %%
 'abc123'.startswith('abcdef')
# Out:
# False

# %%
'abc123'.endswith('12')
# Out:
# False

# %%
'Introduce program'.startswith('Introduce program')
# Out:
# True

# %%
'Introduce program'.endswith('Introduce program')
# Out:
# True

# %% [markdown]
# # 9.join() and split()

# %% [raw]
# #
# `join()`
#  method takes all the items in an iterable,, like a list, dictionary, tuple or set,and joins them into a string

# %%
''.join(['Where' , 'are' ,'you' , 'live'])
# Out:
# 'Whereareyoulive'

# %%
' '.join(['Where' , 'are' ,'you' , 'live'])
# Out:
# 'Where are you live'

# %%
','.join(['Where' , 'are' ,'you' , 'live'])
# Out:
# 'Where,are,you,live'

# %%
' XYZ '.join(['Where' , 'are' ,'you' , 'live'])
# Out:
# 'Where XYZ are XYZ you XYZ live'

# %% [raw]
# 'splits()' method splits a 'string' into a 'list'.

# %%
'We are live in Hyderabad'.split()
# Out:
# ['We', 'are', 'live', 'in', 'Hyderabad']

# %%
'Where XYZ are XYZ you XYZ live'.split('XYZ')
# Out:
# ['Where ', ' are ', ' you ', ' live']

# %%
'We are live in Hyderabad'.split('e')
# Out:
# ['W', ' ar', ' liv', ' in Hyd', 'rabad']

# %%
'We are live in Hyderabad'.split(' ')
# Out:
# ['We', 'are', 'live', 'in', 'Hyderabad']

# %% [markdown]
# # 10.Justifying text with rjust(),ljust() and center()

# %% [raw]
#  'rjust' and 'ljust' will specify a fill character apart from a space character

# %%
'Python'.rjust(10)
# Out:
# '    Python'

# %%
'Python'.ljust(10)
# Out:
# 'Python    '

# %%
'Python'.center(10)
# Out:
# '  Python  '

# %%
'Python'.rjust(15)
# Out:
# '         Python'

# %%
'Python'.center(20)
# Out:
# '       Python       '

# %%
'Python'.rjust(15,'*')
# Out:
# '*********Python'

# %%
'Python'.ljust(10,'-')
# Out:
# 'Python----'

# %%
'Python'.center(10,'=')
# Out:
# '==Python=='

# %% [markdown]
# # 11.Removing whitespace with strip(),rstrip() and lstrip()

# %%
str = '    Hello World     '
str.strip()
# Out:
# 'Hello World'

# %%
'    Hello World     '.lstrip()
# Out:
# 'Hello World     '

# %%
'    Hello World     '.rstrip()
# Out:
# '    Hello World'

# %%
spam = 'WhereXYZareXYZyouXYZlive'
spam.strip('XYZ')
# Out:
# 'WhereXYZareXYZyouXYZlive'

# %% [markdown]
# # 12.The count method

# %%
 sentence = 'one sheep two sheep three sheep four'
sentence.count('sheep')
# Out:
# 3

# %%
sentence.count('e')
# Out:
# 9

# %%
'sentence'.count('e')
# Out:
# 3

# %%
sentence.count('e',6)     #  6 chars since beginning of string
# Out:
# 8

# %%
 sentence.count('e', 9)
# Out:
# 6

# %%
'sentence'.count('e',5)
# Out:
# 1

# %% [markdown]
# # 13.Replace method

# %%
str = 'Hello,World!'

# %%
str.replace('World','Python')
# Out:
# 'Hello,Python!'

# %%
fruits = ' apple,orange,mango,apple'
fruits.replace('apple','cherry',1)
# Out:
# ' cherry,orange,mango,apple'

# %%
fruits = ' apple,orange,mango,apple'
fruits.replace('apple','cherry')
# Out:
# ' cherry,orange,mango,cherry'

# %%
fruits = ' apple,orange,apple,apple'
fruits.replace('apple','cherry',2)
# Out:
# ' cherry,orange,cherry,apple'

# %%
 sentence = "I like apples, Apples are my favorite fruit"
 sentence.replace("apples", "oranges")
# Out:
# 'I like oranges, Apples are my favorite fruit'

# %% [markdown]
# # Python input_questions

# %%
# How do you check if a number entered by the user is positive, negative, or zero? 
num = int(input("Enter your number = "))

if (num > 0):
    print("Positive number")
elif (num < 0):
    print("Negative number")
else:
    print("Zero")
# Out:
# Enter your number =  -67
# Negative number

# %%
# How do you accept a string input and print it in uppercase? 
st = input('Enter your string')
print('uppercase of string = ',st.upper())
# Out:
# Enter your string python
# uppercase of string =  PYTHON

# %%
# Write a Python program that accepts a string and prints the number of vowels in it.
string = input('Enter your string')
vowels = 'aeiou'
count = sum(1 for char in string if char.lower() in vowels)
print('number of vowels:',count)
# Out:
# Enter your string always
# number of vowels: 2

# %%
# a program that takes a number as input and checks if it is even or odd.
num = int(input("Enter your number = "))

if (num % 2 == 0):
    print("Even no.")
else:
    print("Odd no.")
# Out:
# Enter your number =  88
# Even no.

# %%
#  How would you check if a string is a palindrome using `input()`
string = input('Enter your string')
if (string == string[::-1]):
   print('palindrome')
else:
    print('not a palindrome')
# Out:
# Enter your string 678876
# palindrome

# %%
# Write a program that takes a number as input and prints its square. 
num = int(input("Enter your number = "))
print('square = ',num**2)
# Out:
# Enter your number =  11
# square =  121

# %%
# Write a program that asks for a number and prints whether it is divisible by 3.
num = int(input("Enter your number = "))

if num%3==0:
    print("divisible by 3")
else :
    print('not divisible by 3')
# Out:
# Enter your number =  65
# not divisible by 3

# %%
# How would you check if a number is divisible by both 3 and 7?
num = int(input("Enter your number = "))

if (num%3==0 and num%7==0):
    print('number is divisible by both 3 and 7')
else:
    print('number is not divisible by both 3 and 7')
# Out:
# Enter your number =  36
# number is not divisible by both 3 and 7

# %%
# Write a Python program that takes two numbers as input and prints their product
a = int(input("Enter your 1st number = "))
b = int(input("Enter your 2nd number = "))
print('product = ',a * b)
# Out:
# Enter your 1st number =  23
# Enter your 2nd number =  5
# product =  115

# %%
#  Write a program that checks if the input number is a prime number.
num = int(input("Enter given number = "))

if num>1:
    for i in range(2,num):
        if(num%i==0):
            print('Not a prime number')
            break
    else:
        print('prime number')
else:
     print('Not a prime number')
# Out:
# Enter given number =  23
# prime number

# %%
# Write a program that accepts a string and prints the reverse of that string.
str = input("Enter your string = ") 
print('Reverse of string = ',str[::-1])
# Out:
# Enter your string =  happy
# Reverse of string =  yppah

# %%
# Write a program that asks for a user's name and age and prints a message. 
name = input("Enter your name = ") 
age = int(input("Enter your age = "))
print('User name is {} and age is {}'.format(name,age))
# Out:
# Enter your name =  amit
# Enter your age =  22
# User name is amit and age is 22

# %%
# Write a program to calculate the factorial of a number using input(). 
num = int(input("Enter your number = "))
fact = 1
while (num!=0):
    fact = fact * num
    num = num - 1
print('factorial of given no. is ',fact)
# Out:
# Enter your number =  6
# factorial of given no. is  720

# %%
# Write a program to check if an entered number is a perfect square. 
import math

num = int(input("Enter your number = "))
if math.isqrt(num)**2 == num:
    print('Perfect square')
else:
    print('Not a perfect square')
# Out:
# Enter your number =  49
# Perfect square

# %%
#  Write a program that asks for a year and determines if it's a leap year. 
year = int(input("Enter year = "))
if ( year%400==0):
        print('leap year')
elif(year%4==0 and year%100!=0):
        print('leap year')    
else:
    
     print('not a leap year')
# Out:
# Enter year =  2025
# not a leap year

# %%
# * Write a program that accepts a string and counts the occurrence of a particular character.
text =input('Enter a string =')
char = input('Enter a character to count=')
print( f'Occurrence of {char} = {text.count(char)}' )
# Out:
# Enter a string = install
# Enter a character to count= l
# Occurrence of l = 2

# %%
# How would you check if a string contains only alphabets using input()
user_input = input('Enter a string=')
if user_input.isalpha():
    print('Only alphabet')
else:
    print('Contain non-alphabet characters')
# Out:
# Enter a string= are23op
# Contain non-alphabet characters

# %%
# * Write a program to count the number of words in a sentence entered by the user.
text = input('Enter a sentence =')
print('Number of words = ',len(text.split()) )
# Out:
# Enter a sentence = today is wonderful
# Number of words =  3

# %%
# How would you accept a date input from the user in Python? 
from datetime import datetime 
date_str = input("Enter a date (YYYY-MM-DD): ") 
date = datetime.strptime(date_str, "%Y-%m-%d") 
print("Entered date:", date)
# Out:
# Enter a date (YYYY-MM-DD):  2025-11-09
# Entered date: 2025-11-09 00:00:00

# %%
# Write a program that accepts a number and prints whether it is a multiple of 10
num = int(input("Enter your number = "))
if num%10 == 0:
    print('multiple of 10')
else: 
    print('is not multiple of 10')
# Out:
# Enter your number =  340
# multiple of 10

# %%
#Write a program that checks if the entered number is divisible by both 3 and 5.
num = int(input("Enter your number = "))

if (num%3==0 and num%5==0):
    print('number is divisible by both 3 and 5')
else:
    print('number is not divisible by both 3 and 5')
# Out:
# Enter your number =  25
# number is not divisible by both 3 and 5

# %%
# Write a program to swap the values of two variables using input().
a = int(input("Enter your 1st number a = "))
b = int(input("Enter your 2nd number b = "))
a = a + b
b = a - b
a = a - b
print('swap of the value : a = {} and b = {}'.format(a,b))
# Out:
# Enter your 1st number a =  23
# Enter your 2nd number b =  12
# swap of the value : a = 12 and b = 23

# %%
#  Write a program to take user input and print it without spaces between words.
user_input = input("Enter a string: ") 
print(user_input.replace(" ", ""))
# Out:
# Enter a string:  I am doing my work
# Iamdoingmywork

# %%
# Write a program that accepts a number and prints its cube. 
num = int(input("Enter your number = "))
print('cube ',num**3)
# Out:
# Enter your number =  3
# cube  27

# %%
#  How would you accept and store multiple names from the user? 
names = input("Enter names separated by commas: ").split(',') 
print("Names:", names)
# Out:
# Enter names separated by commas:  Ajay ,Ram,krishna,amit
# Names: ['Ajay ', 'Ram', 'krishna', 'amit']

# %%
#  How do you find the maximum number from a list of integers entered by the user? 
l = [21 ,56,44,33,98,67,59,27]
l.sort()
l.reverse()
print('maximum number of list is ',l[0])
# Out:
# maximum number of list is  98

# %%
#  Write a program to check if the entered string has digits. 
user_input = input("Enter a string: ") 
if any(char.isdigit() for char in user_input): 
       print("Contains digits") 
else: 
       print("No digits")
# Out:
# Enter a string:  hell8o
# Contains digits

# %%
#  Write a program to find the sum of all digits in a string entered by the user.
text = input("Enter a string: ") 
digit_sum = sum(int(digit) for digit in text if digit.isdigit()) 
print("Sum of digits:", digit_sum)
# Out:
# Enter a string:  3456
# Sum of digits: 18

# %%
#  Write a program that accepts a number and prints its absolute value. 
num = float(input("Enter your number = "))
print('absolute value of {} is {}'.format(num,abs(num)))
# Out:
# Enter your number =  -9
# absolute value of -9.0 is 9.0

# %%
#  Write a program to find the average of a list of numbers entered by the user. 
numbers = list(map(int, input("Enter numbers separated by space: ").split())) 
print("Average:", sum(numbers) / len(numbers))
# Out:
# Enter numbers separated by space:  2 5 4 1 9 7
# Average: 4.666666666666667

# %%
#  Write a program to count the number of consonants in a string entered by the user.
text = input("Enter a string: ") 
consonants = "bcdfghjklmnpqrstvwxyz" 
count = sum(1 for char in text.lower() if char in consonants) 
print("Number of consonants:", count)
# Out:
# Enter a string:  your name
# Number of consonants: 4

# %%
# * Write a program that accepts a sentence and prints the longest word. 
text = input("Enter a sentence: ") 
words = text.split() 
longest_word = max(words, key=len) 
print("Longest word:", longest_word)
# Out:
# Enter a sentence:  I live in Hyderabad
# Longest word: Hyderabad
